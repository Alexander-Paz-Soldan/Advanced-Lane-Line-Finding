# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
img = cv.imread("apple.jpeg")
plt.imshow(img)

# %%
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
print("Image type: ", type(img_rgb))
print("Image data type: ", img_rgb.dtype)
print("Image shape: ", img_rgb.shape)
# Out:
# Image type:  <class 'numpy.ndarray'>
# Image data type:  uint8
# Image shape:  (240, 210, 3)

# %%
# drawing shapes on the image
line_img = img_rgb.copy() # copy the image
cv.line(line_img, (0,0), (200,200), (0,0,255), 5) # draw the line
plt.imshow(line_img) # show the image

# %%
# draw a rectangle on the image
rectangle_img = img_rgb.copy() # again use a copy
cv.rectangle(rectangle_img, (25,50), (175,200), (0,255,0), 3)
plt.imshow(rectangle_img)

# %%
# text on an image
text_img = img_rgb.copy()
font = cv.FONT_HERSHEY_SIMPLEX
textcolor = (255,255,255)
cv.putText(text_img, "APPLE", (60,130), font, 1, textcolor, 2, cv.LINE_AA)
plt.imshow(text_img)

# %%
# finally saving the image
cv.imwrite("apple_text.jpg", text_img)
# Out:
# True
